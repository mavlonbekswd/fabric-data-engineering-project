# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import urllib.request

url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet"
dest = "/lakehouse/default/Files/yellow_tripdata_2024-01.parquet"

urllib.request.urlretrieve(url, dest)
print("Done")
# Out:
# StatementMeta(, , -1, Cancelled, , Cancelled, True)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/yellow_tripdata_2024-01.parquet"
df = pd.read_parquet("/lakehouse/default/Files/yellow_tripdata_2024-01.parquet")
display(df)
# Out:
# StatementMeta(, 81498e2f-7aee-42f5-b3e9-4cfd31971374, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, f8358866-effe-4cce-8571-4758e0b842ed)

# %%
import requests

url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet"

response = requests.get(url)
with open("/lakehouse/default/Files/yellow_tripdata_2024-01.parquet", "wb") as f:
    f.write(response.content)

print(f"Downloaded {len(response.content)} bytes")
# Out:
# StatementMeta(, fde6d0fd-9f16-4b40-9d19-62cf54e8a533, 5, Finished, Available, Finished, False)
# Downloaded 49961641 bytes

# %%
df = spark.read.parquet("Files/yellow_tripdata_2024-01.parquet")
print(f"Rows: {df.count()}")
print(f"Columns: {len(df.columns)}")
df.printSchema()
# Out:
# StatementMeta(, fde6d0fd-9f16-4b40-9d19-62cf54e8a533, 6, Finished, Available, Finished, False)
# Rows: 2964624
# Columns: 19
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)

# %%
import requests

url = "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"
response = requests.get(url)

with open("/lakehouse/default/Files/taxi_zone_lookup.csv", "wb") as f:
    f.write(response.content)

print("Done")
# Out:
# StatementMeta(, fde6d0fd-9f16-4b40-9d19-62cf54e8a533, 8, Finished, Available, Finished, False)
# Done

# %%
import pandas as pd
zones = pd.read_csv("/lakehouse/default/Files/taxi_zone_lookup.csv")
print(zones.head(10))
# Out:
# StatementMeta(, fde6d0fd-9f16-4b40-9d19-62cf54e8a533, 9, Finished, Available, Finished, False)
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone
# 5           6  Staten Island  Arrochar/Fort Wadsworth    Boro Zone
# 6           7         Queens                  Astoria    Boro Zone
# 7           8         Queens             Astoria Park    Boro Zone
# 8           9         Queens               Auburndale    Boro Zone
# 9          10         Queens             Baisley Park    Boro Zone

# %%
import requests
import json

OPENAQ_KEY = "3da7bd656fe1925a5e0d7a2293b0412e4bccdc36775659ff06a171ba32ebb810"

# v3 uses /v3/sensors/{sensor_id}/measurements or /v3/locations/{id}/latest
# First let's find NYC specific location IDs
url = "https://api.openaq.org/v3/locations"
params = {
    "coordinates": "40.7128,-74.0060",
    "radius": 25000,
    "limit": 10
}
headers = {"X-API-Key": OPENAQ_KEY}

response = requests.get(url, params=params, headers=headers)
print(f"Status: {response.status_code}")
data = response.json()
print(json.dumps(data, indent=2))
# Out:
# StatementMeta(, fde6d0fd-9f16-4b40-9d19-62cf54e8a533, 11, Finished, Available, Finished, False)
# Status: 200
# {
#   "meta": {
#     "name": "openaq-api",
#     "website": "/",
#     "page": 1,
#     "limit": 10,
#     "found": ">10"
#   },
#   "results": [
#     {
#       "id": 384,
#       "name": "CCNY",
#       "locality": "New York-Northern New Jersey-Long Island",
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 671,
#           "name": "o3 ppm",
#           "parameter": {
#             "id": 10,
#             "name": "o3",
#             "units": "ppm",
#             "displayName": "O\u2083"
#           }
#         },
#         {
#           "id": 673,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.8197,
#         "longitude": -73.9481
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -73.9481,
#         40.8197,
#         -73.9481,
#         40.8197
#       ],
#       "distance": 12838.35149267,
#       "datetimeFirst": {
#         "utc": "2016-03-12T09:00:00Z",
#         "local": "2016-03-12T04:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-05-17T13:00:00Z",
#         "local": "2026-05-17T09:00:00-04:00"
#       }
#     },
#     {
#       "id": 386,
#       "name": "Susan Wagner",
#       "locality": null,
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 674,
#           "name": "o3 ppm",
#           "parameter": {
#             "id": 10,
#             "name": "o3",
#             "units": "ppm",
#             "displayName": "O\u2083"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.5969,
#         "longitude": -74.1264
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -74.1264,
#         40.5969,
#         -74.1264,
#         40.5969
#       ],
#       "distance": 16411.29002886,
#       "datetimeFirst": {
#         "utc": "2016-03-25T04:00:00Z",
#         "local": "2016-03-25T00:00:00-04:00"
#       },
#       "datetimeLast": {
#         "utc": "2017-11-15T22:00:00Z",
#         "local": "2017-11-15T17:00:00-05:00"
#       }
#     },
#     {
#       "id": 625,
#       "name": "Manhattan/IS143",
#       "locality": "New York-Northern New Jersey-Long Island",
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 1097,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.8492,
#         "longitude": -73.9319
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -73.9319,
#         40.8492,
#         -73.9319,
#         40.8492
#       ],
#       "distance": 16387.8610642,
#       "datetimeFirst": {
#         "utc": "2016-03-10T08:00:00Z",
#         "local": "2016-03-10T03:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-05-17T13:00:00Z",
#         "local": "2026-05-17T09:00:00-04:00"
#       }
#     },
#     {
#       "id": 626,
#       "name": "Bronx - IS52",
#       "locality": "New York-Northern New Jersey-Long Island",
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 1098,
#           "name": "o3 ppm",
#           "parameter": {
#             "id": 10,
#             "name": "o3",
#             "units": "ppm",
#             "displayName": "O\u2083"
#           }
#         },
#         {
#           "id": 1099,
#           "name": "pm10 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 1,
#             "name": "pm10",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM10"
#           }
#         },
#         {
#           "id": 1102,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.816101,
#         "longitude": -73.902199
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -73.902199,
#         40.816101,
#         -73.902199,
#         40.816101
#       ],
#       "distance": 14436.37757131,
#       "datetimeFirst": {
#         "utc": "2016-03-10T08:00:00Z",
#         "local": "2016-03-10T03:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-05-17T13:00:00Z",
#         "local": "2026-05-17T09:00:00-04:00"
#       }
#     },
#     {
#       "id": 628,
#       "name": "Maspeth",
#       "locality": "New York-Northern New Jersey-Long Island",
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 1103,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.7269,
#         "longitude": -73.8933
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -73.8933,
#         40.7269,
#         -73.8933,
#         40.7269
#       ],
#       "distance": 9649.9470164,
#       "datetimeFirst": {
#         "utc": "2016-03-10T08:00:00Z",
#         "local": "2016-03-10T03:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-05-17T13:00:00Z",
#         "local": "2026-05-17T09:00:00-04:00"
#       }
#     },
#     {
#       "id": 631,
#       "name": "Queens",
#       "locality": "New York-Northern New Jersey-Long Island",
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 1106,
#           "name": "o3 ppm",
#           "parameter": {
#             "id": 10,
#             "name": "o3",
#             "units": "ppm",
#             "displayName": "O\u2083"
#           }
#         },
#         {
#           "id": 1152,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.7375,
#         "longitude": -73.8244
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -73.8244,
#         40.7375,
#         -73.8244,
#         40.7375
#       ],
#       "distance": 15585.49988562,
#       "datetimeFirst": {
#         "utc": "2016-03-10T08:00:00Z",
#         "local": "2016-03-10T03:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-05-17T13:00:00Z",
#         "local": "2026-05-17T09:00:00-04:00"
#       }
#     },
#     {
#       "id": 642,
#       "name": "PS 19",
#       "locality": null,
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 1121,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.73,
#         "longitude": -73.984459
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -73.984459,
#         40.73,
#         -73.984459,
#         40.73
#       ],
#       "distance": 2638.27744008,
#       "datetimeFirst": {
#         "utc": "2016-03-10T08:00:00Z",
#         "local": "2016-03-10T03:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2017-12-18T10:00:00Z",
#         "local": "2017-12-18T05:00:00-05:00"
#       }
#     },
#     {
#       "id": 648,
#       "name": "Bklyn - PS 314",
#       "locality": "KINGS",
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 1128,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.641819,
#         "longitude": -74.018707
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -74.018707,
#         40.641819,
#         -74.018707,
#         40.641819
#       ],
#       "distance": 7955.14843457,
#       "datetimeFirst": {
#         "utc": "2016-03-10T08:00:00Z",
#         "local": "2016-03-10T03:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-05-17T13:00:00Z",
#         "local": "2026-05-17T09:00:00-04:00"
#       }
#     },
#     {
#       "id": 662,
#       "name": "Division Street",
#       "locality": null,
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 1143,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.7142,
#         "longitude": -73.995
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -73.995,
#         40.7142,
#         -73.995,
#         40.7142
#       ],
#       "distance": 942.39515405,
#       "datetimeFirst": {
#         "utc": "2016-03-10T08:00:00Z",
#         "local": "2016-03-10T03:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2020-02-19T16:00:00Z",
#         "local": "2020-02-19T11:00:00-05:00"
#       }
#     },
#     {
#       "id": 664,
#       "name": "Bklyn - PS274",
#       "locality": "New York-Northern New Jersey-Long Island",
#       "timezone": "America/New_York",
#       "country": {
#         "id": 155,
#         "code": "US",
#         "name": "United States"
#       },
#       "owner": {
#         "id": 4,
#         "name": "Unknown Governmental Organization"
#       },
#       "provider": {
#         "id": 119,
#         "name": "AirNow"
#       },
#       "isMobile": false,
#       "isMonitor": true,
#       "instruments": [
#         {
#           "id": 2,
#           "name": "Government Monitor"
#         }
#       ],
#       "sensors": [
#         {
#           "id": 1145,
#           "name": "pm25 \u00b5g/m\u00b3",
#           "parameter": {
#             "id": 2,
#             "name": "pm25",
#             "units": "\u00b5g/m\u00b3",
#             "displayName": "PM2.5"
#           }
#         }
#       ],
#       "coordinates": {
#         "latitude": 40.694401,
#         "longitude": -73.928596
#       },
#       "licenses": [
#         {
#           "id": 33,
#           "name": "US Public Domain",
#           "attribution": {
#             "name": "Unknown Governmental Organization",
#             "url": null
#           },
#           "dateFrom": "2016-01-30",
#           "dateTo": null
#         }
#       ],
#       "bounds": [
#         -73.928596,
#         40.694401,
#         -73.928596,
#         40.694401
#       ],
#       "distance": 6853.14547276,
#       "datetimeFirst": {
#         "utc": "2016-03-10T08:00:00Z",
#         "local": "2016-03-10T03:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-05-17T13:00:00Z",
#         "local": "2026-05-17T09:00:00-04:00"
#       }
#     }
#   ]
# }

# %%
import requests
import json

url = "https://api.worldbank.org/v2/country/USA/indicator/NY.GDP.MKTP.CD"
params = {
    "format": "json",
    "per_page": 20,
    "mrv": 10  # most recent 10 years
}

response = requests.get(url, params=params)
print(f"Status: {response.status_code}")
data = response.json()
print(json.dumps(data[1][:3], indent=2))
# Out:
# StatementMeta(, e4b37174-3497-4a74-88ae-694d323ccc3b, 17, Finished, Available, Finished, False)
# Status: 200
# [
#   {
#     "indicator": {
#       "id": "NY.GDP.MKTP.CD",
#       "value": "GDP (current US$)"
#     },
#     "country": {
#       "id": "US",
#       "value": "United States"
#     },
#     "countryiso3code": "USA",
#     "date": "2024",
#     "value": 28750956130731.2,
#     "unit": "",
#     "obs_status": "",
#     "decimal": 0
#   },
#   {
#     "indicator": {
#       "id": "NY.GDP.MKTP.CD",
#       "value": "GDP (current US$)"
#     },
#     "country": {
#       "id": "US",
#       "value": "United States"
#     },
#     "countryiso3code": "USA",
#     "date": "2023",
#     "value": 27292170793214.4,
#     "unit": "",
#     "obs_status": "",
#     "decimal": 0
#   },
#   {
#     "indicator": {
#       "id": "NY.GDP.MKTP.CD",
#       "value": "GDP (current US$)"
#     },
#     "country": {
#       "id": "US",
#       "value": "United States"
#     },
#     "countryiso3code": "USA",
#     "date": "2022",
#     "value": 25604848907611,
#     "unit": "",
#     "obs_status": "",
#     "decimal": 0
#   }
# ]

# %%
import requests
import json

OPENAQ_KEY = "3da7bd656fe1925a5e0d7a2293b0412e4bccdc36775659ff06a171ba32ebb810"

# Pull latest measurements from NYC location ID 384 (CCNY)
url = "https://api.openaq.org/v3/locations/384/sensors"
headers = {"X-API-Key": OPENAQ_KEY}

response = requests.get(url, headers=headers)
print(f"Status: {response.status_code}")
data = response.json()
print(json.dumps(data, indent=2))
# Out:
# StatementMeta(, e4b37174-3497-4a74-88ae-694d323ccc3b, 26, Finished, Available, Finished, False)
# Status: 200
# {
#   "meta": {
#     "name": "openaq-api",
#     "website": "/",
#     "page": 1,
#     "limit": 100,
#     "found": 2
#   },
#   "results": [
#     {
#       "id": 673,
#       "name": "pm25 \u00b5g/m\u00b3",
#       "parameter": {
#         "id": 2,
#         "name": "pm25",
#         "units": "\u00b5g/m\u00b3",
#         "displayName": "PM2.5"
#       },
#       "datetimeFirst": {
#         "utc": "2016-03-12T09:00:00Z",
#         "local": "2016-03-12T04:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-04-26T19:00:00Z",
#         "local": "2026-04-26T15:00:00-04:00"
#       },
#       "coverage": {
#         "expectedCount": 1,
#         "expectedInterval": "01:00:00",
#         "observedCount": 57706,
#         "observedInterval": "57706:00:00",
#         "percentComplete": 5770600.0,
#         "percentCoverage": 5770600.0,
#         "datetimeFrom": {
#           "utc": "2016-03-12T09:00:00Z",
#           "local": "2016-03-12T04:00:00-05:00"
#         },
#         "datetimeTo": {
#           "utc": "2026-04-26T19:00:00Z",
#           "local": "2026-04-26T15:00:00-04:00"
#         }
#       },
#       "latest": {
#         "datetime": {
#           "utc": "2026-04-26T19:00:00Z",
#           "local": "2026-04-26T15:00:00-04:00"
#         },
#         "value": 3.7,
#         "coordinates": {
#           "latitude": 40.8197,
#           "longitude": -73.9481
#         }
#       },
#       "summary": {
#         "min": -4.9,
#         "q02": null,
#         "q25": null,
#         "median": null,
#         "q75": null,
#         "q98": null,
#         "max": 151.5,
#         "avg": 7.064731261761605,
#         "sd": null
#       }
#     },
#     {
#       "id": 671,
#       "name": "o3 ppm",
#       "parameter": {
#         "id": 10,
#         "name": "o3",
#         "units": "ppm",
#         "displayName": "O\u2083"
#       },
#       "datetimeFirst": {
#         "utc": "2016-03-12T09:00:00Z",
#         "local": "2016-03-12T04:00:00-05:00"
#       },
#       "datetimeLast": {
#         "utc": "2026-04-26T19:00:00Z",
#         "local": "2026-04-26T15:00:00-04:00"
#       },
#       "coverage": {
#         "expectedCount": 1,
#         "expectedInterval": "01:00:00",
#         "observedCount": 58430,
#         "observedInterval": "58430:00:00",
#         "percentComplete": 5843000.0,
#         "percentCoverage": 5843000.0,
#         "datetimeFrom": {
#           "utc": "2016-03-12T09:00:00Z",
#           "local": "2016-03-12T04:00:00-05:00"
#         },
#         "datetimeTo": {
#           "utc": "2026-04-26T19:00:00Z",
#           "local": "2026-04-26T15:00:00-04:00"
#         }
#       },
#       "latest": {
#         "datetime": {
#           "utc": "2026-04-26T19:00:00Z",
#           "local": "2026-04-26T15:00:00-04:00"
#         },
#         "value": 0.042,
#         "coordinates": {
#           "latitude": 40.8197,
#           "longitude": -73.9481
#         }
#       },
#       "summary": {
#         "min": 0.0,
#         "q02": null,
#         "q25": null,
#         "median": null,
#         "q75": null,
#         "q98": null,
#         "max": 0.108,
#         "avg": 0.02549028087483307,
#         "sd": null
#       }
#     }
#   ]
# }

# %%
import requests
import json

OPENAQ_KEY = "3da7bd656fe1925a5e0d7a2293b0412e4bccdc36775659ff06a171ba32ebb810"

# Pull PM2.5 measurements from CCNY sensor 673 for Jan 2024
url = "https://api.openaq.org/v3/sensors/673/measurements"
params = {
    "date_from": "2024-01-01T00:00:00Z",
    "date_to": "2024-01-31T23:59:59Z",
    "limit": 1000
}
headers = {"X-API-Key": OPENAQ_KEY}

response = requests.get(url, params=params, headers=headers)
print(f"Status: {response.status_code}")
data = response.json()
print(f"Records found: {data['meta']['found']}")

# Save to Bronze
with open("/lakehouse/default/Files/openaq_nyc_pm25.json", "w") as f:
    json.dump(data['results'], f)

print(f"Saved {len(data['results'])} records")
print(json.dumps(data['results'][0], indent=2))
# Out:
# StatementMeta(, e4b37174-3497-4a74-88ae-694d323ccc3b, 27, Finished, Available, Finished, False)
# Status: 200
# Records found: >1000
# Saved 1000 records
# {
#   "value": 2.4,
#   "flagInfo": {
#     "hasFlags": false
#   },
#   "parameter": {
#     "id": 2,
#     "name": "pm25",
#     "units": "\u00b5g/m\u00b3",
#     "displayName": null
#   },
#   "period": {
#     "label": "raw",
#     "interval": "01:00:00",
#     "datetimeFrom": {
#       "utc": "2016-03-12T08:00:00Z",
#       "local": "2016-03-12T03:00:00-05:00"
#     },
#     "datetimeTo": {
#       "utc": "2016-03-12T09:00:00Z",
#       "local": "2016-03-12T04:00:00-05:00"
#     }
#   },
#   "coordinates": null,
#   "summary": null,
#   "coverage": {
#     "expectedCount": 1,
#     "expectedInterval": "01:00:00",
#     "observedCount": 1,
#     "observedInterval": "01:00:00",
#     "percentComplete": 100.0,
#     "percentCoverage": 100.0,
#     "datetimeFrom": {
#       "utc": "2016-03-12T08:00:00Z",
#       "local": "2016-03-12T03:00:00-05:00"
#     },
#     "datetimeTo": {
#       "utc": "2016-03-12T09:00:00Z",
#       "local": "2016-03-12T04:00:00-05:00"
#     }
#   }
# }

# %%
import requests
import json

url = "https://api.worldbank.org/v2/country/USA/indicator/NY.GDP.MKTP.CD"
params = {
    "format": "json",
    "per_page": 20,
    "mrv": 10
}

response = requests.get(url, params=params)
records = response.json()[1]

# Save as JSON to Bronze
with open("/lakehouse/default/Files/usa_gdp.json", "w") as f:
    json.dump(records, f)

print(f"Saved {len(records)} GDP records")
# Out:
# StatementMeta(, e4b37174-3497-4a74-88ae-694d323ccc3b, 18, Finished, Available, Finished, False)
# Saved 10 GDP records

# %%
import requests

url = "https://data-api.ecb.europa.eu/service/data/EXR/D.USD.EUR.SP00.A?format=csvdata"
response = requests.get(url)

with open("/lakehouse/default/Files/ecb_fx_usd_eur.csv", "wb") as f:
    f.write(response.content)

print(f"Downloaded {len(response.content)} bytes")

import pandas as pd
fx = pd.read_csv("/lakehouse/default/Files/ecb_fx_usd_eur.csv")
print(fx.shape)
print(fx.tail(3))
# Out:
# StatementMeta(, e4b37174-3497-4a74-88ae-694d323ccc3b, 29, Finished, Available, Finished, False)
# Downloaded 1461550 bytes
# (7054, 32)
#                        KEY FREQ CURRENCY CURRENCY_DENOM EXR_TYPE EXR_SUFFIX  \
# 7051  EXR.D.USD.EUR.SP00.A    D      USD            EUR     SP00          A
# 7052  EXR.D.USD.EUR.SP00.A    D      USD            EUR     SP00          A
# 7053  EXR.D.USD.EUR.SP00.A    D      USD            EUR     SP00          A
#
#      TIME_PERIOD  OBS_VALUE OBS_STATUS OBS_CONF  ...  COMPILATION  COVERAGE  \
# 7051  2026-04-22     1.1733          A        F  ...          NaN       NaN
# 7052  2026-04-23     1.1694          A        F  ...          NaN       NaN
# 7053  2026-04-24     1.1712          A        F  ...          NaN       NaN
#
#      DECIMALS  NAT_TITLE SOURCE_AGENCY  SOURCE_PUB  \
# 7051        4        NaN           4F0         NaN
# 7052        4        NaN           4F0         NaN
# 7053        4        NaN           4F0         NaN
#
#                                            TITLE  \
# 7051  US dollar/Euro ECB reference exchange rate
# 7052  US dollar/Euro ECB reference exchange rate
# 7053  US dollar/Euro ECB reference exchange rate
#
#                                             TITLE_COMPL  UNIT  UNIT_MULT
# 7051  ECB reference exchange rate, US dollar/Euro, 2...   USD          0
# 7052  ECB reference exchange rate, US dollar/Euro, 2...   USD          0
# 7053  ECB reference exchange rate, US dollar/Euro, 2...   USD          0
#
# [3 rows x 32 columns]

# %%
# ============================================================
# INTEGRATION 3: Weather Data via Open-Meteo API
# Fetch NYC hourly weather for January 2024
# Aligned with taxi data: Jan 2024
# ============================================================
import requests
import json
from datetime import datetime

LAT, LON = 40.7128, -74.0060

url = "https://archive-api.open-meteo.com/v1/archive"
params = {
    "latitude": LAT,
    "longitude": LON,
    "start_date": "2024-01-01",
    "end_date": "2024-01-31",
    "hourly": "temperature_2m,precipitation,windspeed_10m,weathercode",
    "timezone": "America/New_York"
}

response = requests.get(url, params=params)
print(f"Weather API Status: {response.status_code}")
weather = response.json()

times = weather['hourly']['time']
temps = weather['hourly']['temperature_2m']
precip = weather['hourly']['precipitation']
wind = weather['hourly']['windspeed_10m']
wcode = weather['hourly']['weathercode']

records = [
    {
        'timestamp': t,
        'temperature_c': temp,
        'precipitation_mm': prec,
        'windspeed_kmh': ws,
        'weathercode': wc,
        'measurement': 'nyc_weather',
        'location': 'NYC'
    }
    for t, temp, prec, ws, wc in zip(times, temps, precip, wind, wcode)
]

with open('/lakehouse/default/Files/nyc_weather_jan2024.json', 'w') as f:
    json.dump(records, f, indent=2)

print(f"Saved {len(records)} hourly weather records for Jan 2024")
print(f"Date range: {times[0]} to {times[-1]}")
print(json.dumps(records[0], indent=2))

# InfluxDB line protocol (for Grafana integration)
print('\n--- InfluxDB Line Protocol sample (first 3 rows) ---')
for r in records[:3]:
    ts_ns = int(datetime.fromisoformat(r['timestamp']).timestamp() * 1e9)
    print(f"nyc_weather,location=NYC temperature_c={r['temperature_c']},precipitation_mm={r['precipitation_mm']},windspeed_kmh={r['windspeed_kmh']} {ts_ns}")

# %%
# ============================================================
# Weather → Silver Delta table (time-series, Grafana-ready)
# ============================================================
from pyspark.sql import functions as F

BRONZE = 'abfss://FabricDataProject@onelake.dfs.fabric.microsoft.com/Bronze.Lakehouse/Files'

df_weather_raw = spark.read.option('multiline', 'true').json(f'{BRONZE}/nyc_weather_jan2024.json')

df_weather = df_weather_raw.select(
    F.to_timestamp('timestamp').alias('datetime'),
    F.to_date('timestamp').alias('date'),
    F.hour(F.to_timestamp('timestamp')).alias('hour'),
    F.col('temperature_c').cast('double'),
    F.col('precipitation_mm').cast('double'),
    F.col('windspeed_kmh').cast('double'),
    F.col('weathercode').cast('integer'),
    F.col('location'),
    F.col('measurement')
).filter(
    (F.col('date') >= '2024-01-01') & (F.col('date') <= '2024-01-31')
)

df_weather.write.format('delta').mode('overwrite').saveAsTable('silver_weather')
print(f'silver_weather: {df_weather.count()} hourly records')
df_weather.show(5, truncate=False)

# --- Grafana Note ---
# To visualize in Grafana:
# 1. Install Grafana OSS (local) or Grafana Cloud
# 2. Add Microsoft Fabric / Azure SQL data source pointing to GoldWarehouse
# 3. Query: SELECT datetime, temperature_c, precipitation_mm FROM silver_weather
#    ORDER BY datetime
# 4. Use Time series panel with datetime as X axis
print('\nGrafana: Use silver_weather table with GoldWarehouse SQL endpoint')
print('Query: SELECT datetime, temperature_c, precipitation_mm, windspeed_kmh FROM silver_weather ORDER BY datetime')

# %%
# ============================================================
# FIX: Correlation Analysis - Both datasets aligned to Jan 2024
# PROBLEM: Dashboard was comparing 2024 taxi vs 2016-2017 AQ data
# FIX: Both silver_taxi and silver_air_quality now cover Jan 2024
# ============================================================
from pyspark.sql import functions as F

# Load silver_taxi (Jan 2024)
df_taxi = spark.table('silver_taxi').select(
    'pickup_date', 'pickup_hour', 'trip_distance', 'fare_amount', 'trip_duration_min'
)

# Aggregate taxi by date + hour
df_taxi_hourly = df_taxi.groupBy('pickup_date', 'pickup_hour').agg(
    F.count('*').alias('trip_count'),
    F.avg('trip_distance').alias('avg_distance_miles'),
    F.avg('fare_amount').alias('avg_fare_usd'),
    F.avg('trip_duration_min').alias('avg_duration_min')
)

# Load silver_air_quality (Jan 2024 - CCNY sensor 673)
df_aq = spark.table('silver_air_quality').select(
    'date', 'hour', 'pm25_value'
).filter(
    (F.col('date') >= '2024-01-01') & (F.col('date') <= '2024-01-31')
)

# Data alignment verification
taxi_min, taxi_max = df_taxi_hourly.agg(F.min('pickup_date'), F.max('pickup_date')).collect()[0]
aq_min, aq_max = df_aq.agg(F.min('date'), F.max('date')).collect()[0]
print(f'Taxi data:       {taxi_min} to {taxi_max}')
print(f'Air quality:     {aq_min} to {aq_max}')
print(f'Aligned: {taxi_min == aq_min and taxi_max >= aq_max}')

# Join on date + hour
df_corr = df_taxi_hourly.join(
    df_aq,
    (df_taxi_hourly.pickup_date == df_aq.date) &
    (df_taxi_hourly.pickup_hour == df_aq.hour),
    'inner'
).select(
    df_taxi_hourly.pickup_date.alias('date'),
    df_taxi_hourly.pickup_hour.alias('hour'),
    'trip_count', 'avg_distance_miles', 'avg_fare_usd', 'avg_duration_min', 'pm25_value'
)

print(f'\nCorrelation rows: {df_corr.count()}')
df_corr.orderBy('date', 'hour').show(10)

# Save to Gold
df_corr.write.format('delta').mode('overwrite').saveAsTable('gold_taxi_aq_correlation')
print('\ngold_taxi_aq_correlation saved to Gold lakehouse')

# Pearson correlations
corr1 = df_corr.stat.corr('trip_count', 'pm25_value')
corr2 = df_corr.stat.corr('avg_fare_usd', 'pm25_value')
corr3 = df_corr.stat.corr('avg_distance_miles', 'pm25_value')
print(f'\nPearson: trip_count vs pm25_value      = {corr1:.4f}')
print(f'Pearson: avg_fare_usd vs pm25_value     = {corr2:.4f}')
print(f'Pearson: avg_distance_miles vs pm25_value= {corr3:.4f}')

# %%
# ============================================================
# INTEGRATION 4a: Install Great Expectations
# ============================================================
# %pip install great-expectations==0.18.15 --quiet
print('Great Expectations installed')

# %%
# ============================================================
# INTEGRATION 4b: Great Expectations Validation + Teams Bot
# Validates silver_taxi and silver_air_quality
# Sends Teams webhook alert on failure
# ============================================================
import great_expectations as gx
from great_expectations.dataset import SparkDFDataset
import requests

# --- Teams Incoming Webhook URL ---
# Create at: Teams > Channel > ... > Connectors > Incoming Webhook
TEAMS_WEBHOOK_URL = "https://your-org.webhook.office.com/webhookb2/YOUR-WEBHOOK-ID"

def send_teams_alert(title, message, color='FF0000'):
    """Post a Teams message card when validation fails/passes."""
    payload = {
        '@type': 'MessageCard',
        '@context': 'http://schema.org/extensions',
        'themeColor': color,
        'summary': title,
        'sections': [{
            'activityTitle': f'Data Quality Alert: {title}',
            'activitySubtitle': 'Great Expectations — FabricDataProject',
            'facts': [{'name': 'Details', 'value': message}],
            'markdown': True
        }]
    }
    try:
        r = requests.post(TEAMS_WEBHOOK_URL, json=payload, timeout=10)
        print(f'Teams webhook: HTTP {r.status_code}')
    except Exception as e:
        print(f'Teams webhook not configured yet: {e}')

# ---- Validate silver_taxi ----
print('=' * 60)
print('Validating silver_taxi...')
df_taxi = spark.table('silver_taxi')
ge_taxi = SparkDFDataset(df_taxi)

taxi_results = []
taxi_results.append(('tpep_pickup_datetime not null',
    ge_taxi.expect_column_values_to_not_be_null('tpep_pickup_datetime').success))
taxi_results.append(('trip_distance in [0.01, 500]',
    ge_taxi.expect_column_values_to_be_between('trip_distance', min_value=0.01, max_value=500).success))
taxi_results.append(('fare_amount in [0.01, 5000]',
    ge_taxi.expect_column_values_to_be_between('fare_amount', min_value=0.01, max_value=5000).success))
taxi_results.append(('row_count in [1M, 5M]',
    ge_taxi.expect_table_row_count_to_be_between(min_value=1_000_000, max_value=5_000_000).success))
taxi_results.append(('pickup_date within Jan 2024',
    ge_taxi.expect_column_values_to_be_between('pickup_date', min_value='2024-01-01', max_value='2024-01-31').success))

print('\n--- silver_taxi ---')
taxi_failures = []
for name, ok in taxi_results:
    print(f'  {"PASS" if ok else "FAIL"}: {name}')
    if not ok: taxi_failures.append(f'silver_taxi: {name}')

# ---- Validate silver_air_quality ----
print('\n' + '=' * 60)
print('Validating silver_air_quality...')
df_aq = spark.table('silver_air_quality')
ge_aq = SparkDFDataset(df_aq)

aq_results = []
aq_results.append(('pm25_value in [0, 500]',
    ge_aq.expect_column_values_to_be_between('pm25_value', min_value=0, max_value=500).success))
aq_results.append(('datetime not null',
    ge_aq.expect_column_values_to_not_be_null('datetime').success))
aq_results.append(('date within Jan 2024 — alignment check',
    ge_aq.expect_column_values_to_be_between('date', min_value='2024-01-01', max_value='2024-01-31').success))
aq_results.append(('pm25_value column exists',
    ge_aq.expect_column_to_exist('pm25_value').success))

print('\n--- silver_air_quality ---')
aq_failures = []
for name, ok in aq_results:
    print(f'  {"PASS" if ok else "FAIL"}: {name}')
    if not ok: aq_failures.append(f'silver_air_quality: {name}')

# ---- Validate silver_weather (new integration) ----
print('\n' + '=' * 60)
print('Validating silver_weather...')
df_w = spark.table('silver_weather')
ge_w = SparkDFDataset(df_w)

weather_results = []
weather_results.append(('datetime not null',
    ge_w.expect_column_values_to_not_be_null('datetime').success))
weather_results.append(('temperature_c in [-40, 60]',
    ge_w.expect_column_values_to_be_between('temperature_c', min_value=-40, max_value=60).success))
weather_results.append(('row_count = 744 (31 days * 24h)',
    ge_w.expect_table_row_count_to_be_between(min_value=700, max_value=800).success))

print('\n--- silver_weather ---')
weather_failures = []
for name, ok in weather_results:
    print(f'  {"PASS" if ok else "FAIL"}: {name}')
    if not ok: weather_failures.append(f'silver_weather: {name}')

# ---- BOT TRIGGER ----
print('\n' + '=' * 60)
all_failures = taxi_failures + aq_failures + weather_failures
if all_failures:
    msg = 'Validation failures:\n' + '\n'.join(f'- {f}' for f in all_failures)
    print(f'VALIDATION FAILED: {len(all_failures)} checks failed')
    send_teams_alert('Data Validation FAILED', msg, color='FF0000')
else:
    print('ALL VALIDATIONS PASSED')
    send_teams_alert('Data Validation PASSED', 'All checks passed for silver_taxi, silver_air_quality, silver_weather', color='00CC00')
